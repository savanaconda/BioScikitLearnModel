# %%
# %run bio_model.py --plot
# Out:
# 1. Importing and set up data...
# 2. Visualizing data exploration...
# Numerical data:
#         LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082   103.685262   443.639726    46.549315
# std      22.024023    9981.264932   180.569112   456.098091   161.319273
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      60.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      70.049958    9478.500000     0.000000   383.500000     0.000000
# 75%      79.000000   11601.500000   164.250000   712.250000     0.000000
# max     313.000000  215245.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000  ...
# ...

# %%
# %run bio_model.py
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# 1. Importing and set up data...
# 2. Skipping plotting...
# 3. Preprocessing...
# 4. Setting up model and running pipeline...
# 5. Cross validating and processing results...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Programming/Python/bio-modeling/bio_model.py:82
#      80 elapsed_time = time.time() - start
#      81 scores = cv["test_score"]
# ---> 82 train_indices_fold_0 = cv['indices'][0][0]
#      83 test_indices_fold_0 = cv['indices'][0][1]
#      84 print(train_indices_fold_0)
#
# KeyError: 0
